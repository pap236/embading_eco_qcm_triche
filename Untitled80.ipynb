# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
emb1 = model.encode("""Dans le cadre du modèle IS-LM en économie fermée, supposons qu’une banque centrale augmente fortement l’offre de monnaie, tandis que le gouvernement décide simultanément de réduire ses dépenses publiques.
Laquelle des affirmations suivantes est la plus correcte concernant l’effet à court terme de cette politique mixte sur la production (Y) et le taux d’intérêt (i) ?
""", convert_to_tensor=True)

embs = [
    model.encode("La production augmente et le taux d’intérêt diminue, car l’expansion monétaire est plus efficace en présence d’un multiplicateur élevé.", convert_to_tensor=True),
    model.encode("La production diminue et le taux d’intérêt augmente, car la contraction budgétaire domine.", convert_to_tensor=True),
    model.encode("La production reste inchangée et le taux d’intérêt baisse, car les effets opposés des politiques budgétaire et monétaire se compensent.", convert_to_tensor=True),
    model.encode("La production augmente fortement, mais le taux d’intérêt reste inchangé car la courbe LM est parfaitement élastique.", convert_to_tensor=True)
]



for (item, value) in enumerate(embs):
  similarity = util.pytorch_cos_sim(emb1, value)
  print(f"Score de similarité {item}:{similarity.item()}")
# Out:
# Score de similarité 0:0.520879864692688
# Score de similarité 1:0.5566825866699219
# Score de similarité 2:0.5718098878860474
# Score de similarité 3:0.510851263999939

# %%
import pandas as pd


data = pd.read_csv("/content/qcm_economie_complexe.csv")
data.head()
# Out:
#                                             Question  \
# 0  Dans le modèle IS-LM, que se passe-t-il si l'o...
# 1  Dans le modèle Mundell-Fleming avec taux de ch...
# 2  Quel est l'effet d'une anticipation d'inflatio...
# 3  Dans une économie en sous-emploi, quel est l’e...
# 4  Pourquoi la politique monétaire est-elle ineff...
#
#                                             Option A  \
# 0  La production diminue et le taux d’intérêt aug...
# 1  Le taux de change se déprécie et la production...
# 2  Elle se déplace vers la droite, avec plus d’in...
# 3            Une baisse du multiplicateur keynésien.
# 4          Parce que la courbe IS devient verticale.
#
#                                             Option B  \
# 0  La production augmente et le taux d’intérêt di...
# 1  La politique est inefficace, car la banque cen...
# 2  Elle devient verticale car l'inflation anticip...
# 3             Une augmentation de l’épargne globale.
# 4  Parce que la courbe LM est plate, rendant le t...
#
#                                             Option C  \
# 0  La production reste inchangée et le taux d’int...
# 1  Le taux d’intérêt baisse, entraînant une fuite...
# 2  Elle se déplace vers la gauche, car les salair...
# 3  Une hausse du revenu d’équilibre par le jeu du...
# 4  Parce que les agents anticipent une hausse fut...
#
#                                             Option D Réponse
# 0  La production augmente fortement, mais le taux...       C
# 1  La production augmente temporairement avant de...       B
# 2  Elle s’aplatit à cause de l’inertie de l’infla...       A
# 3     Un déplacement vers la gauche de la courbe IS.       C
# 4  Parce que la demande d'investissement devient ...       B
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('Question').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Option A').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('Option B').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('Option C').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Option A'].value_counts()
#     for x_label, grp in _df_4.groupby('Question')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Question')
# _ = plt.ylabel('Option A')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Option B'].value_counts()
#     for x_label, grp in _df_5.groupby('Option A')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Option A')
# _ = plt.ylabel('Option B')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Option C'].value_counts()
#     for x_label, grp in _df_6.groupby('Option B')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Option B')
# _ = plt.ylabel('Option C')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Option D'].value_counts()
#     for x_label, grp in _df_7.groupby('Option C')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Option C')
# _ = plt.ylabel('Option D')

# %%
print(data.shape)
print(data.columns)
# Out:
# (5, 6)
# Index(['Question', 'Option A', 'Option B', 'Option C', 'Option D', 'Réponse'], dtype='object')

# %%
df = pd.read_csv("qcm_economie_complexe.csv")

# Colonnes attendues : 'question', 'option_1', 'option_2', 'option_3', 'option_4'
scores_max = []
index_max = []

for index, row in df.iterrows():
    question = row['Question']
    options = [row['Option A'], row['Option B'], row['Option C'], row['Option D']]

    # Encodage des phrases
    emb_q = model.encode(question, convert_to_tensor=True)
    emb_opts = model.encode(options, convert_to_tensor=True)

    # Similarité cosinus
    sims = util.pytorch_cos_sim(emb_q, emb_opts)[0]  # shape: [4]
    scores = sims.tolist()  # convert to list of floats

    # Trouver le score max et son index
    max_score = max(scores)

    max_index = scores.index(max_score)

    scores_max.append(max_score)
    index_max.append(max_index)

# Ajout des nouvelles colonnes
df['max_similarity_score'] = scores_max
df['best_option_index'] = index_max

# Export vers un nouveau fichier
df['best_option_index']
# Out:
# 0    1
# 1    1
# 2    1
# 3    2
# 4    3
# Name: best_option_index, dtype: int64

# %%
df.to_csv("qcm_avec_scores.csv", index=False)

print("Fichier exporté avec les scores de similarité.")
# Out:
# Fichier exporté avec les scores de similarité.
